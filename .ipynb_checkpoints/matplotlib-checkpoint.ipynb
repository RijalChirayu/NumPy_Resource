# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic graph

# %%
x = np.arange(0 , 10 , 0.5 )
y = np.sin(x)
fig , ax = plt.subplots()
ax.plot(x , y)

# %%
x = [1,2,3]
y = [1 ,4 ,9]
plt.plot(x ,y)
plt.show()
